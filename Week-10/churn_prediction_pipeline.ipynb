# %% [markdown]
# # Week 10: Customer Churn Preprocessing Pipeline
#
# Data preprocessing and feature engineering for churn prediction.

# %% [markdown]
# ## 1. Load and Inspect Data

# %%
import pandas as pd

df = pd.read_csv('churn_data.csv')
df.head()

# %%
df.info()
df.describe(include='all')

# %% [markdown]
# ## 2. Run Complete Pipeline

# %%
# %run churn_prediction_pipeline.py

# %% [markdown]
# ## 3. Review Pipeline Metrics

# %%
pd.read_csv('pipeline_model_metrics.csv')

# %% [markdown]
# ## 4. Review Feature Selection

# %%
pd.read_csv('selected_features.csv').head(10)

# %% [markdown]
# ## 5. Visual Evidence

# %%
from IPython.display import Image, display
for file in ['churn_distribution.png', 'feature_selection.png', 'confusion_matrix.png']:
    display(Image(filename=file))
