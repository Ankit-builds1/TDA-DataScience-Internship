# %% [markdown]
# # Week 11: Customer Segmentation & Prediction

# %%
import pandas as pd

df = pd.read_csv('segmentation_data.csv')
df.head()

# %%
df.info()
df.describe(include='all')

# %% [markdown]
# ## Run the full segmentation and modeling workflow

# %%
# %run customer_segmentation.py

# %% [markdown]
# ## Segment Profiles

# %%
pd.read_csv('segment_profiles.csv')

# %% [markdown]
# ## Model Evaluation Results

# %%
pd.read_csv('model_evaluation_results.csv')

# %% [markdown]
# ## Visual Documentation

# %%
from IPython.display import Image, display
for file in ['elbow_method.png', 'customer_segments.png', 'segment_churn_rates.png']:
    display(Image(filename=file))
