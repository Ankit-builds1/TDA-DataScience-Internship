# %% [markdown]
# # Week 12 Final Capstone Project
#
# End-to-end data science workflow with modeling, reports, presentation, and deployment demo.

# %%
import pandas as pd
for file in ['sales_data.csv', 'house_prices.csv', 'customer_churn.csv']:
    df = pd.read_csv('data/' + file)
    print(file, df.shape)
    display(df.head())

# %% [markdown]
# ## Run Full Pipeline

# %%
# %run src/capstone_pipeline.py

# %% [markdown]
# ## Review Results

# %%
import json
from pathlib import Path
metrics = json.loads(Path('reports/capstone_metrics.json').read_text())
metrics

# %% [markdown]
# ## Visual Evidence

# %%
from IPython.display import Image, display
for file in ['sales_trend.png', 'house_predictions.png', 'churn_distribution.png']:
    display(Image(filename='reports/figures/' + file))
