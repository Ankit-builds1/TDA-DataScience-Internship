# %% [markdown]
# # Week 9: House Price Prediction
#
# Machine learning project using house price data.

# %% [markdown]
# ## 1. Load Libraries and Data

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path('house_data.csv')
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()
df.describe(include='all')

# %% [markdown]
# ## 2. Train Models and Evaluate Performance

# %%
# %run house_price_prediction.py

# %% [markdown]
# ## 3. Review Generated Metrics

# %%
pd.read_csv('model_metrics.csv')

# %% [markdown]
# ## 4. Visualize Predictions vs Actual Values

# %%
from IPython.display import Image
Image(filename='predictions_vs_actual.png')

# %% [markdown]
# ## 5. Feature Importance

# %%
pd.read_csv('feature_importance.csv').head(10)
