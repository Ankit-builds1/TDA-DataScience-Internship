# %% [markdown]
# # Week 6: Interactive Sales Dashboard
#
# This notebook summarizes the Week 6 Seaborn and Plotly dashboard workflow.

# %%
import pandas as pd
from analysis import load_sales_data, prepare_sales_data, summarize_dashboard, format_inr

df = prepare_sales_data(load_sales_data("sales_data.csv"))
summary = summarize_dashboard(df)
metrics = summary["metrics"]

print("INTERACTIVE SALES DASHBOARD")
print("Total Revenue:", format_inr(metrics.total_revenue))
print("Total Orders:", metrics.total_orders)
print("Average Order Value:", format_inr(metrics.average_order_value))
print("Top Product:", metrics.top_product)
print("Top Region:", metrics.top_region)
print("Best Month:", metrics.best_month)
summary["product_summary"], summary["region_summary"], summary["monthly_summary"], summary["correlation"]
# Out:
# INTERACTIVE SALES DASHBOARD
# Total Revenue: INR 12,365,048
# Total Orders: 100
# Average Order Value: INR 123,650
# Top Product: Laptop
# Top Region: North
# Best Month: 2024-03
# (            Revenue  Orders  Units  Average_Order_Value  Average_Price
#  Product
#  Laptop      3889210      24    136        162050.416667   27651.500000
#  Tablet      2884340      26    127        110936.153846   24177.230769
#  Phone       2859394      20    101        142969.700000   27379.000000
#  Headphones  1384033      15     48         92268.866667   28692.133333
#  Monitor     1348071      15     66         89871.400000   20709.666667,
#          Revenue  Orders  Units  Average_Order_Value
#  Region
#  North   3983635      28    147        142272.678571
#  South   3737852      27    143        138438.962963
#  East    2519639      19     94        132612.578947
#  West    2123922      26     94         81689.307692,
#           Revenue  Orders  Units  Average_Order_Value
#  Month
# ...

# %% [markdown]
# ## Dashboard Outputs
#
# Run `python dashboard.py` to create Seaborn statistical charts, the Plotly interactive HTML dashboard, the dashboard GIF, output CSV files, and reports.
